# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import pandas as pd
import phase2_common as ph2
from s4bb.spectra import XSpec, CalcSpec_namaster
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


params_withpbs = np.load('mlsearch_hf/att1/ph2_mlsearch_f1_y20_n3_full_withpbs.npy')

# params_withpbs = params_withpbs.T

# print(params_withpbs)
columns = ['status', 'fval', 'r', 'A_d',
'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s']

df_withpbs = pd.DataFrame(params_withpbs.T, columns = columns)
print(df_withpbs.describe())
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  381.988744    0.000133   14.288771   -0.808153    1.650403
# std       0.0   25.826360    0.000333    0.551773    0.038763    0.006614
# min       0.0  323.956856   -0.000727   13.695381   -0.877395    1.635024
# 25%       0.0  363.273927   -0.000108   13.733252   -0.843803    1.645015
# 50%       0.0  379.576701    0.000116   14.366464   -0.803183    1.649975
# 75%       0.0  399.802419    0.000357   14.827352   -0.774300    1.656154
# max       0.0  446.170183    0.001063   15.192410   -0.684311    1.664127
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.069125   -0.960455   -3.091992    0.023300    0.999253    0.999204
# std      0.022248    0.049600    0.012894    0.011520    0.000270    0.000339
# min      1.034919   -1.098735   -3.131336   -0.008935    0.998598    0.998040
# 25%      1.056036   -0.990650   -3.101719    0.015753    0.999080    0.998951
# 50%      1.063822   -0.960782   -3.092617    0.024802    0.999213    0.999230
# 75%      1.075396   -0.927607   -3.083046    0.030766    0.999425    0.999431
# max      1.146886   -0.864611   -3.061318    0.048665    1.000072    0.999997
