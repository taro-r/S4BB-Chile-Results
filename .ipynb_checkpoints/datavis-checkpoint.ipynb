# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import pandas as pd
import phase2_common as ph2
from s4bb.spectra import XSpec, CalcSpec_namaster
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


params_withpbs = np.load('mlsearch/ph2_mlsearch_f1_y20_n4_full_withpbs.npy')

# params_withpbs = params_withpbs.T

# print(params_withpbs)

df_withpbs = pd.DataFrame(params_withpbs.T, columns = ['status', 'fval', 'r', 'A_d',
'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s'])

# print(df_withpbs)
print(df_withpbs.describe())
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  378.840004    0.000174   14.520567   -0.827303    1.650505
# std       0.0   32.231462    0.000288    0.745240    0.049775    0.006495
# min       0.0  291.178970   -0.000721   13.697502   -0.917422    1.633436
# 25%       0.0  360.341656   -0.000007   13.738875   -0.868436    1.645900
# 50%       0.0  377.693201    0.000181   14.712175   -0.845057    1.649798
# 75%       0.0  402.014128    0.000390   15.179626   -0.781779    1.654257
# max       0.0  458.929132    0.000875   16.035488   -0.684663    1.665882
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.051569   -0.947691   -3.093536    0.023883    0.999247    0.999211
# std      0.017498    0.049683    0.012975    0.011868    0.000314    0.000385
# min      1.016868   -1.099122   -3.127587   -0.006043    0.998218    0.997697
# 25%      1.040507   -0.980548   -3.102932    0.016354    0.999032    0.998970
# 50%      1.050323   -0.948753   -3.093410    0.024696    0.999212    0.999217
# 75%      1.059358   -0.914470   -3.084867    0.032226    0.999461    0.999495
# max      1.120475   -0.834735   -3.064025    0.058672    1.000231    1.000054
