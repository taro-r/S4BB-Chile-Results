# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import pandas as pd
import phase2_common as ph2
from s4bb.spectra import XSpec, CalcSpec_namaster
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


params_withpbs = np.load('mlsearch/ph2_mlsearch_f1_y20_n3_full_withpbs.npy')

# params_withpbs = params_withpbs.T

# print(params_withpbs)

df_withpbs = pd.DataFrame(params_withpbs.T, columns = ['status', 'fval', 'r', 'A_d',
'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s'])

# print(df_withpbs)
print(df_withpbs.describe())
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  381.461009    0.000169   14.279172   -0.806630    1.650337
# std       0.0   26.046423    0.000333    0.570514    0.041277    0.006602
# min       0.0  322.926464   -0.000688   13.695865   -0.869752    1.635012
# 25%       0.0  362.233948   -0.000066   13.733019   -0.846913    1.644753
# 50%       0.0  379.508279    0.000156   13.944629   -0.792646    1.649629
# 75%       0.0  397.922923    0.000389   14.845035   -0.773075    1.655909
# max       0.0  446.941789    0.001015   15.146144   -0.684307    1.664097
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.064984   -0.954518   -3.091883    0.023414    0.999255    0.999201
# std      0.017866    0.053194    0.013106    0.011731    0.000279    0.000343
# min      1.027847   -1.098731   -3.131908   -0.009508    0.998575    0.998047
# 25%      1.053278   -0.985227   -3.101057    0.015173    0.999069    0.998961
# 50%      1.060702   -0.945184   -3.092382    0.024654    0.999218    0.999228
# 75%      1.073268   -0.922945   -3.082481    0.031091    0.999435    0.999456
# max      1.128133   -0.858959   -3.061185    0.049627    1.000072    0.999997
