# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import h5py
import numpy as np
import pandas as pd
import phase2_common as ph2
from s4bb.spectra import XSpec, CalcSpec_namaster

# %%
with h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/noisemod/seeded/gauss_n100/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f1, \
     h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/noisemod/seeded/gauss_n100/phase2_spec_noise_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f2, \
     h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/noisemod/seeded/gauss_n100/phase2_spec_llcdm_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f3, \
     h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/seeded/baseline_nlat3/phase2_spec_noise_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f4:
     spec1 = XSpec.from_hdf5(f1)
     spec2 = XSpec.from_hdf5(f2)
     spec3 = XSpec.from_hdf5(f3)
     spec4 = XSpec.from_hdf5(f4)

ell_centers = 0.5 * (spec1.bins[0] + spec1.bins[1])


ps_mean1 = np.mean(spec1.spec, axis=2)
ps_mean2 = np.mean(spec2.spec, axis=2)
ps_mean3 = np.mean(spec3.spec, axis=2)
ps_mean4 = np.mean(spec4.spec, axis=2)
#ps_mean4 = spec4.spec[:,:,25]

print(len(spec1.spec[0,0,:]))
spec_names1 = spec1.str()
spec_names2 = spec2.str()
spec_names3 = spec3.str()


print(len(spec_names1) == len(spec2.str())) # Ensure same number of maps for coherency check
print(len(spec_names1))
print(len(spec2.str()))
#print(spec_names1)
#print(spec2.str())
ncols = 6
nplots = spec1.nspec()





larr = []
count = 0
for l in range(nplots):
    if "LT" in f'{spec_names1[l]}':
        larr.append(l)
        count += 1

nrows = int(np.ceil(count / ncols))
counter = 0
print(larr)
print(f'{spec_names2[1]}')
i=13


plt.figure()
plt.plot(ell_centers, ps_mean2[i], marker='o', linestyle='-', color='red', label='comb',alpha=0.75,ms=4)
plt.plot(ell_centers, 900*ps_mean4[i], marker='^', linestyle=':', color='green', label='noise',alpha=0.75,ms=4)
plt.plot(ell_centers, ps_mean3[i], marker='s', color='blue', label='llcdm',alpha=0.75,ms=4)

plt.xlabel(r'$\ell$')
plt.ylabel(r'$C_\ell$')
plt.title(f'{spec_names3[i]} (with pbs)')
plt.grid()
plt.legend()
plt.show()
    # print(f'{spec_names1[i]}')
    
for j in range(len(ps_mean1[i])):
    print(ps_mean2[i][j]/(10000*ps_mean4[i][j]))
'''    if str(ps_mean1[i][j]) != str(ps_mean2[i][j]+ps_mean3[i][j]):
        print(i, str(ps_mean1[i][j]), str(ps_mean2[i][j]), 'bad')
    else: print('good')'''
# Out:
# 100
# True
# 105
# 105
# [12, 13, 25, 26, 37, 38, 48, 49, 58, 59, 67, 68, 75, 76, 82, 83, 88, 89, 93, 94, 97, 98, 100, 101, 102, 103, 104]
# LF-1_B [noise] x LF-1_B [noise]
# 0.9999999999999996
# 1.0000000000000002
# 0.9999999999999998
# 1.0000000000000002
# 1.0
# 1.0000000000000002
# 1.0000000000000002
# 0.9999999999999998
# 1.0
# 0.9999999999999998
# 0.9999999999999998
# 0.9999999999999999
# 1.0000000000000002
# 0.9999999999999998
# 0.9999999999999998
# 0.9999999999999998
# 0.9999999999999998
# 1.0
# 0.9999999999999999
# 1.0
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000004
# 1.0000000000000002
# "    if str(ps_mean1[i][j]) != str(ps_mean2[i][j]+ps_mean3[i][j]):\n        print(i, str(ps_mean1[i][j]), str(ps_mean2[i][j]), 'bad')\n    else: print('good')"

# %%
# extremely interesting - comb spectra are exactly 2x (cross) or 4x (power); signal spectra (simtype llcdm) are not

# for ONLY lensing template graphs
# /global/cfs/cdirs/cmbs4/chile_optimization/analysis/cbischoff/phase2/spectra/phase2_spec_comb_f1_y20_n4_full_withpbs_000_100.h5
# CHLAT 4 Veronica script comb vs signoi
with h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/inj_noise/seeded/gauss_n100/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f1, \
     h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/inj_noise/seeded/gauss_n100/phase2_spec_noise_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f2, \
     h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/inj_noise/seeded/gauss_n100/phase2_spec_llcdm_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f3:
     spec1 = XSpec.from_hdf5(f1)
     spec2 = XSpec.from_hdf5(f2)
     spec3 = XSpec.from_hdf5(f3)

ell_centers = 0.5 * (spec1.bins[0] + spec1.bins[1])

# spec1.spec = (1+2*(0.5 - np.random.rand(spec1.shape[0],spec1.shape[1],spec1.shape[2])))*spec1.spec
#spec1.spec = 2 * spec1.spec
ps_mean1 = np.mean(spec1.spec, axis=2)
ps_mean2 = np.mean(spec2.spec, axis=2)
ps_mean3 = np.mean(spec3.spec, axis=2)

print(len(spec1.spec[0,0,:]))
spec_names1 = spec1.str()
spec_names2 = spec2.str()
spec_names3 = spec3.str()


print(len(spec_names1) == len(spec2.str())) # Ensure same number of maps for coherency check
print(len(spec_names1))
print(len(spec2.str()))
print(spec_names1==spec2.str())
#print(spec2.str())
ncols = 6
nplots = spec1.nspec()

larr = []
count = 0
for l in range(nplots):
    if "LT" in f'{spec_names1[l]}':
        larr.append(l)
        count += 1

nrows = int(np.ceil(count / ncols))
fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4 * nrows))
axes = axes.flatten()
counter = 0
print(larr)
for i in larr:
    ax = axes[counter]
    ax.plot(ell_centers, ps_mean1[i], marker='o', linestyle='-', color='red', label='comb')
    ax.plot(ell_centers, ps_mean2[i], marker='s', linestyle='--', color='blue', label='noise')
    ax.plot(ell_centers, ps_mean3[i], marker='^', linestyle=':', color='green', label='llcdm')
    ax.set_xlabel(r'$\ell$')
    ax.set_ylabel(r'$C_\ell$')
    ax.set_title(f'{spec_names1[i]} (with pbs)')
    
    # print(f'{spec_names1[i]}')
    ax.grid()
    ax.legend()
    for j in range(len(ps_mean1[i])):
        if str(ps_mean1[i][j]) != str(ps_mean2[i][j]+ps_mean3[i][j]):
            print(i, str(ps_mean1[i][j]), str(ps_mean2[i][j]+ps_mean3[i][j]), 'bad')

        else:
            print('good')
    counter += 1
    print(counter)
for j in range(count, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
# yuck
'''for j in range(len(ps_mean1[i])):
        if str(2*ps_mean1[i][j]) != str(ps_mean2[i][j]) and str(4*ps_mean1[i][j]) != str(ps_mean2[i][j]):
            print(i, str(ps_mean1[i][j]), str(ps_mean2[i][j]), 'bad')'''

# %%
# /global/cfs/cdirs/cmbs4/chile_optimization/analysis/cbischoff/phase2/spectra/phase2_spec_comb_f1_y20_n4_full_withpbs_000_100.h5
# CHLAT 4 Veronica script comb vs signoi
with h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/inj_noise/seeded/gauss_stn40/phase2_spec_llcdm_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f1, \
     h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/seeded/baseline_nlat3/phase2_spec_llcdm_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f2:
    spec1 = XSpec.from_hdf5(f1)
    spec2 = XSpec.from_hdf5(f2)

ell_centers = 0.5 * (spec1.bins[0] + spec1.bins[1])

ps_mean1 = np.mean(spec1.spec, axis=2)
ps_mean2 = np.mean(spec2.spec, axis=2)

spec_names1 = spec1.str()

print(len(spec_names1) == len(spec2.str())) # Ensure same number of maps for coherency check
print(len(spec_names1))
print(len(spec2.str()))
#print(spec_names1)
#print(spec2.str())
ncols = 6
nplots = spec1.nspec()
nrows = int(np.ceil(nplots / ncols))

fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4 * nrows))

axes = axes.flatten()



for i in range(nplots):
    ax = axes[i]
    ax.plot(ell_centers, ps_mean1[i], marker='o', linestyle='-', color='red', label='baseline')
    ax.plot(ell_centers, ps_mean2[i], marker='s', linestyle='--', color='blue', label='modified')
    ax.set_xlabel(r'$\ell$')
    ax.set_ylabel(r'$C_\ell$')
    ax.set_title(f'{spec_names1[i]} (with pbs)')
#    print(f'{spec_names1[i]}')
    ax.grid()
    ax.legend()
    for j in range(len(ps_mean1[i])):
        if str(ps_mean1[i][j]) != str(ps_mean2[i][j]):
            print(i, str(ps_mean1[i][j]), str(ps_mean2[i][j]), 'bad')
for j in range(nplots, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
# yuck
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 3
#       1 # /global/cfs/cdirs/cmbs4/chile_optimization/analysis/cbischoff/phase2/spectra/phase2_spec_comb_f1_y20_n4_full_withpbs_000_100.h5
#       2 # CHLAT 4 Veronica script comb vs signoi
# ----> 3 with h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/inj_noise/seeded/gauss_stn40/phase2_spec_llcdm_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f1, \
#       4      h5py.File('/global/u1/t/trama/Projects/ChileResults/spectra/seeded/baseline_nlat3/phase2_spec_llcdm_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f2:
#       5     spec1 = XSpec.from_hdf5(f1)
#       6     spec2 = XSpec.from_hdf5(f2)
#
# ...

# %%
print(ps_mean1[8],ps_mean2[8])
print(ps_mean1[13],ps_mean2[13])
# Out:
# [ 0.48901926  0.66090712  0.91040627  1.29279768  1.36098117  1.50209952
#   1.2664374   1.11085191  0.95544238  1.10463743  1.87172979  3.51345796
#   6.06616219  9.28799341 12.70029076 16.41519492 19.69058567 21.62230429
#  21.79887303 20.41992404 18.02133686 14.97037855 11.39265771  9.11115684] [ 0.48901926  0.66090712  0.91040627  1.29279768  1.36098117  1.50209952
#   1.2664374   1.11085191  0.95544238  1.10463743  1.87172979  3.51345796
#   6.06616219  9.28799341 12.70029076 16.41519492 19.69058567 21.62230429
#  21.79887303 20.41992404 18.02133686 14.97037855 11.39265771  9.11115684]
# [0.00046517 0.0010632  0.00187189 0.00296082 0.00440229 0.00599511
#  0.00808491 0.01040464 0.01325667 0.01617334 0.01961428 0.02276131
#  0.02591045 0.03060441 0.03465706 0.03676934 0.03922073 0.04138045
#  0.04474512 0.04790145 0.05045866 0.05527883 0.05876291 0.06829822] [0.00046517 0.0010632  0.00187189 0.00296082 0.00440229 0.00599511
# ...

# %%
with h5py.File('spectra/seeded/baseline_nlat3/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f1, \
     h5py.File('spectra/seeded/baseline_nlat4/phase2_spec_comb_f1_y20_n4_full_withpbs_000_100.h5', 'r') as f2, \
     h5py.File('spectra/seeded/baseline_nlat5/phase2_spec_comb_f1_y20_n5_full_withpbs_000_100.h5', 'r') as f3, \
     h5py.File('spectra/LTmod/seeded/2x/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f4, \
     h5py.File('spectra/LTmod/seeded/hf/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f5 :
     spec1 = XSpec.from_hdf5(f1)
     spec2 = XSpec.from_hdf5(f2)
     spec3 = XSpec.from_hdf5(f3)
     spec4 = XSpec.from_hdf5(f4)
     spec5 = XSpec.from_hdf5(f5)


ell_centers = 0.5 * (spec1.bins[0] + spec1.bins[1])

# spec1.spec = (1+2*(0.5 - np.random.rand(spec1.shape[0],spec1.shape[1],spec1.shape[2])))*spec1.spec
#spec1.spec = 2 * spec1.spec
ps_mean1 = np.mean(spec1.spec, axis=2)
ps_mean2 = np.mean(spec2.spec, axis=2)
ps_mean3 = np.mean(spec3.spec, axis=2)
ps_mean4 = np.mean(spec4.spec, axis=2)
ps_mean5 = np.mean(spec5.spec, axis=2)

print(len(spec1.spec[0,0,:]))
spec_names1 = spec1.str()


print(len(spec_names1) == len(spec2.str())) # Ensure same number of maps for coherency check
print(len(spec_names1))
print(len(spec2.str()))
#print(spec_names1)
#print(spec2.str())
ncols = 6
nplots = spec1.nspec()


spectradict = {'NLAT 3': {'data': ps_mean1, 'marker': 'o', 'linestyle':'-' , 'color': 'b'},
               'NLAT 4': {'data': ps_mean2, 'marker': 's', 'linestyle':'--', 'color': 'r'},
               'NLAT 5': {'data': ps_mean3, 'marker': '^', 'linestyle': ':', 'color': 'g'},
               'Doubled Lensing Template': {'data': ps_mean4, 'color': 'C3'},
               'Halved Lensing Template': {'data': ps_mean5, 'color': 'C4'},              }




j=13
plots1 = [['NLAT 3','NLAT 4'],['NLAT 3','NLAT 5'],['NLAT 4','NLAT 5']]

n1cols = 2
n1plots = 3
n1rows = 2
print(spec_names1[j])

#fig1, axes1 = plt.subplots(n1rows, n1cols, figsize=(4.5 * n1cols, 4 * n1rows))
#axes1 = axes1.flatten()

fig1 = plt.figure(figsize=(5 * n1cols, 4 * n1rows))
gs1 = gridspec.GridSpec(4, 4)

ax11 = plt.subplot(gs1[:2, :2])

ax12 = plt.subplot(gs1[:2, 2:])

ax13 = plt.subplot(gs1[2:4, 1:3])

axes1 = [ax11,ax12,ax13]


for i in range(n1plots):
    plotnames = plots1[i]
    plot1 = plots1[i][0]
    plot2 = plots1[i][1]
    plot_title = plot1 + ' & ' + plot2
    
    graph1 = spectradict[plot1]['data']
    c1 = spectradict[plot1]['color']
    m1 = spectradict[plot1]['marker']
    l1 = spectradict[plot1]['linestyle']
    graph2 = spectradict[plot2]['data']
    c2 = spectradict[plot2]['color']
    m2 = spectradict[plot2]['marker']
    l2 = spectradict[plot2]['linestyle']

    ax = axes1[i]
#    ax.plot(ell_centers, graph1[j], marker='o', linestyle='-', color='red', label=plot1,alpha=0.75,ms=4)
#    ax.plot(ell_centers, graph2[j], marker='s', linestyle='--', color='blue', label=plot2,alpha=0.75,ms=4)

    ax.plot(ell_centers, graph1[j], marker=m1, linestyle=l1, color=c1, label=plot1,alpha=0.75,ms=4)
    ax.plot(ell_centers, graph2[j], marker=m2, linestyle=l2, color=c2, label=plot2,alpha=0.75,ms=4)

    ax.set_xlabel(r'$\ell$')
    ax.set_ylabel(r'$C_\ell$')
    ax.set_title(plot_title)
#    ax.ticklabel_format(axis='x', style='sci', scilimits=(0,0)) 
    ax.legend()   # might be too much visual clutter
    ax.grid()
    
plt.tight_layout()



'''
plt.figure()
plt.plot(ell_centers, ps_mean1[i], marker='o', linestyle='-', color='red', label='Unmodified LT',alpha=0.75,ms=4)
#plt.plot(ell_centers, ps_mean2[i], marker='s', linestyle='--', color='blue', label='Modified LT',alpha=0.75,ms=4)
plt.plot(ell_centers, ps_mean2[i], marker='^', linestyle=':', color='green', label='Modified LT',alpha=0.75,ms=4)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$C_\ell$')
plt.title(f'{spec_names1[i]} (with pbs)')
plt.grid()
plt.legend()
plt.show()
    # print(f'{spec_names1[i]}')
    
for j in range(len(ps_mean1[i])):
        if str(4*ps_mean1[i][j]) != str(ps_mean2[i][j]):
            print(i, str(ps_mean1[i][j]), str(ps_mean2[i][j]), 'bad')
        else: print('good')
'''
# Out:
# 100
# True
# 105
# 105
# LT_B [lensing_template] x LT_B [lensing_template]
# "\nplt.figure()\nplt.plot(ell_centers, ps_mean1[i], marker='o', linestyle='-', color='red', label='Unmodified LT',alpha=0.75,ms=4)\n#plt.plot(ell_centers, ps_mean2[i], marker='s', linestyle='--', color='blue', label='Modified LT',alpha=0.75,ms=4)\nplt.plot(ell_centers, ps_mean2[i], marker='^', linestyle=':', color='green', label='Modified LT',alpha=0.75,ms=4)\nplt.xlabel(r'$\\ell$')\nplt.ylabel(r'$C_\\ell$')\nplt.title(f'{spec_names1[i]} (with pbs)')\nplt.grid()\nplt.legend()\nplt.show()\n    # print(f'{spec_names1[i]}')\n    \nfor j in range(len(ps_mean1[i])):\n        if str(4*ps_mean1[i][j]) != str(ps_mean2[i][j]):\n            print(i, str(ps_mean1[i][j]), str(ps_mean2[i][j]), 'bad')\n        else: print('good')\n"

# %%
with h5py.File('spectra/seeded/baseline_nlat3/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f1, \
     h5py.File('spectra/seeded/baseline_nlat4/phase2_spec_comb_f1_y20_n4_full_withpbs_000_100.h5', 'r') as f2, \
     h5py.File('spectra/seeded/baseline_nlat5/phase2_spec_comb_f1_y20_n5_full_withpbs_000_100.h5', 'r') as f3, \
     h5py.File('spectra/LTmod/seeded/2x/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f4, \
     h5py.File('spectra/LTmod/seeded/hf/phase2_spec_comb_f1_y20_n3_full_withpbs_000_100.h5', 'r') as f5 :
     spec1 = XSpec.from_hdf5(f1)
     spec2 = XSpec.from_hdf5(f2)
     spec3 = XSpec.from_hdf5(f3)
     spec4 = XSpec.from_hdf5(f4)
     spec5 = XSpec.from_hdf5(f5)


ell_centers = 0.5 * (spec1.bins[0] + spec1.bins[1])

# spec1.spec = (1+2*(0.5 - np.random.rand(spec1.shape[0],spec1.shape[1],spec1.shape[2])))*spec1.spec
#spec1.spec = 2 * spec1.spec
ps_mean1 = np.mean(spec1.spec, axis=2)
ps_mean2 = np.mean(spec2.spec, axis=2)
ps_mean3 = np.mean(spec3.spec, axis=2)
ps_mean4 = np.mean(spec4.spec, axis=2)
ps_mean5 = np.mean(spec5.spec, axis=2)

print(len(spec1.spec[0,0,:]))
spec_names1 = spec1.str()


print(len(spec_names1) == len(spec2.str())) # Ensure same number of maps for coherency check
print(len(spec_names1))
print(len(spec2.str()))
#print(spec_names1)
#print(spec2.str())
ncols = 6
nplots = spec1.nspec()


spectradict = {'NLAT 3': {'data': ps_mean1, 'marker': 'o', 'linestyle':'-' , 'color': 'b'},
               'NLAT 4': {'data': ps_mean2, 'marker': 's', 'linestyle':'--', 'color': 'r'},
               'NLAT 5': {'data': ps_mean3, 'marker': '^', 'linestyle': ':', 'color': 'g'},
               'Doubled Lensing Template': {'data': ps_mean4, 'color': 'b'},
               'Halved Lensing Template': {'data': ps_mean5, 'color': 'k'},              }




j=13
plots2 = [['NLAT 4','Doubled Lensing Template'],['NLAT 4','Halved Lensing Template'],
          ['NLAT 5','Doubled Lensing Template'],['NLAT 5','Halved Lensing Template']]

n2cols = 2
n2plots = 4
n2rows = 2
print(spec_names1[i])

fig2, axes2 = plt.subplots(n2rows, n2cols, figsize=(4.5 * n2cols, 4 * n2rows))
axes2 = axes2.flatten()

for i in range(n2plots):
    plotnames = plots2[i]
    plot1 = plots2[i][0]
    plot2 = plots2[i][1]
    plot_title = plot1 + ' & ' + plot2
    
    graph1 = spectradict[plot1]['data']
    graph2 = spectradict[plot2]['data']

    ax = axes2[i]
    ax.plot(ell_centers, graph1[j], marker='o', linestyle='-', color=spectradict[plot1]['color'], label=plot1 ,alpha=0.75,ms=4)
    ax.plot(ell_centers, graph2[j], marker='s', linestyle='--', color=spectradict[plot2]['color'], label=plot2 ,alpha=0.75,ms=4)
    ax.set_xlabel(r'$\ell$')
    ax.set_ylabel(r'$C_\ell$')
    ax.set_title(plot_title)
#    ax.ticklabel_format(axis='x', style='sci', scilimits=(0,0)) 
    ax.legend()   # might be too much visual clutter
    ax.grid()
    
plt.tight_layout()



'''
plt.figure()
plt.plot(ell_centers, ps_mean1[i], marker='o', linestyle='-', color='red', label='Unmodified LT',alpha=0.75,ms=4)
#plt.plot(ell_centers, ps_mean2[i], marker='s', linestyle='--', color='blue', label='Modified LT',alpha=0.75,ms=4)
plt.plot(ell_centers, ps_mean2[i], marker='^', linestyle=':', color='green', label='Modified LT',alpha=0.75,ms=4)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$C_\ell$')
plt.title(f'{spec_names1[i]} (with pbs)')
plt.grid()
plt.legend()
plt.show()
    # print(f'{spec_names1[i]}')
    
for j in range(len(ps_mean1[i])):
        if str(4*ps_mean1[i][j]) != str(ps_mean2[i][j]):
            print(i, str(ps_mean1[i][j]), str(ps_mean2[i][j]), 'bad')
        else: print('good')
'''
# Out:
# 100
# True
# 105
# 105
# LF-2_B x LF-2_B
# "\nplt.figure()\nplt.plot(ell_centers, ps_mean1[i], marker='o', linestyle='-', color='red', label='Unmodified LT',alpha=0.75,ms=4)\n#plt.plot(ell_centers, ps_mean2[i], marker='s', linestyle='--', color='blue', label='Modified LT',alpha=0.75,ms=4)\nplt.plot(ell_centers, ps_mean2[i], marker='^', linestyle=':', color='green', label='Modified LT',alpha=0.75,ms=4)\nplt.xlabel(r'$\\ell$')\nplt.ylabel(r'$C_\\ell$')\nplt.title(f'{spec_names1[i]} (with pbs)')\nplt.grid()\nplt.legend()\nplt.show()\n    # print(f'{spec_names1[i]}')\n    \nfor j in range(len(ps_mean1[i])):\n        if str(4*ps_mean1[i][j]) != str(ps_mean2[i][j]):\n            print(i, str(ps_mean1[i][j]), str(ps_mean2[i][j]), 'bad')\n        else: print('good')\n"
