# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import pandas as pd
import phase2_common as ph2
from s4bb.spectra import XSpec, CalcSpec_namaster
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


params_withpbs = np.load('mlsearch/ph2_mlsearch_f1_y20_n4_full_withpbs.npy')

# params_withpbs = params_withpbs.T

# print(params_withpbs)

df_withpbs = pd.DataFrame(params_withpbs.T, columns = ['status', 'fval', 'r', 'A_d',
'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s'])

# print(df_withpbs)
print(df_withpbs.describe())
# Out:
#        status        fval             r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  1.000000e+02  100.000000  100.000000  100.000000
# mean      0.0  385.257125  1.980251e-04   14.114559   -0.797079    1.650430
# std       0.0   27.249483  2.910812e-04    0.537280    0.038229    0.006258
# min       0.0  320.529470 -7.763874e-04   13.695563   -0.881046    1.634644
# 25%       0.0  366.315225  3.475094e-07   13.732305   -0.839002    1.645785
# 50%       0.0  379.260458  2.230348e-04   13.739038   -0.776992    1.649890
# 75%       0.0  405.585702  4.018457e-04   14.721295   -0.768359    1.654685
# max       0.0  455.231299  8.686476e-04   15.266117   -0.740926    1.664753
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.066758   -0.956959   -3.092475    0.023064    0.999232    0.999206
# std      0.017000    0.047430    0.012477    0.011613    0.000280    0.000361
# min      1.025097   -1.085982   -3.128642   -0.012307    0.998487    0.997773
# 25%      1.055658   -0.988650   -3.101766    0.014565    0.999029    0.998958
# 50%      1.063692   -0.955470   -3.091099    0.024706    0.999213    0.999259
# 75%      1.073006   -0.925667   -3.083996    0.029526    0.999425    0.999468
# max      1.129785   -0.863911   -3.062506    0.048296    1.000056    1.000008
