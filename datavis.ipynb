# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import pandas as pd
import phase2_common as ph2
from s4bb.spectra import XSpec, CalcSpec_namaster
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


params_withpbs = np.load('mlsearch/seeded/baseline_ph2_mlsearch_f1_y20_n3_full_withpbs.npy')
params_withpbs2 = np.load('mlsearch/inj_noise/seeded/mult/mult_n3/att2_ph2_mlsearch_f1_y20_n3_full_withpbs.npy')


# params_withpbs = params_withpbs.T

# print(params_withpbs)
columns = ['status', 'fval', 'r', 'A_d',
'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s']

df_withpbs = pd.DataFrame(params_withpbs.T, columns = columns)
df_withpbs2 = pd.DataFrame(params_withpbs2.T, columns = columns)

r_diff = df_withpbs2['r'] - df_withpbs['r']

print(df_withpbs.describe())
print(df_withpbs2.describe())

r_diffn = r_diff.to_numpy()
print(r_diffn.mean(), r_diffn.std())

# print(df_withpbs)
# print(df_withpbs.describe())
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  381.553543    0.000164   14.220897   -0.802834    1.650375
# std       0.0   26.309056    0.000332    0.565287    0.041703    0.006529
# min       0.0  324.244405   -0.000693   13.699262   -0.872558    1.635022
# 25%       0.0  363.335803   -0.000062   13.732486   -0.843514    1.645368
# 50%       0.0  379.055963    0.000153   13.743557   -0.780262    1.649509
# 75%       0.0  400.616202    0.000390   14.855939   -0.772189    1.655464
# max       0.0  445.391926    0.001100   15.176561   -0.683959    1.664131
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.065122   -0.954638   -3.092231    0.023782    0.999242    0.999206
# ...
