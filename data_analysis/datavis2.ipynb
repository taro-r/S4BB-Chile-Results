# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import pandas as pd
import phase2_common as ph2
from s4bb.spectra import XSpec, CalcSpec_namaster
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


params_withpbs = np.load('/global/cfs/cdirs/cmbs4/chile_optimization/analysis/cbischoff/phase2/mlsearch/ph2_mlsearch_f1_y20_n4_full_withpbs.npy')
params_withpbs2 = np.load('mlsearch/ph2_mlsearch_f1_y20_n4_full_withpbs.npy')


# params_withpbs = params_withpbs.T

# print(params_withpbs)
columns = ['status', 'fval', 'r', 'A_d',
'alpha_d', 'beta_d', 'A_s', 'alpha_s', 'beta_s', 'epsilon', 'Delta_d', 'Delta_s']

df_withpbs = pd.DataFrame(params_withpbs.T, columns = columns)
df_withpbs2 = pd.DataFrame(params_withpbs2.T, columns = columns)

r_diff = df_withpbs['r'] - df_withpbs2['r']

print(df_withpbs.describe())
print(df_withpbs2.describe())

r_diffn = r_diff.to_numpy()
print(r_diffn.mean(), r_diffn.std())
# Out:
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  385.652097    0.000201   14.150060   -0.796825    1.650414
# std       0.0   27.481335    0.000294    0.548306    0.042110    0.006348
# min       0.0  322.079102   -0.000838   13.695655   -0.869048    1.631288
# 25%       0.0  367.257650    0.000011   13.730941   -0.838884    1.645788
# 50%       0.0  382.843549    0.000212   13.739421   -0.779053    1.649881
# 75%       0.0  406.167829    0.000411   14.780179   -0.770058    1.654577
# max       0.0  455.563326    0.000857   15.157491   -0.686054    1.664868
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.067899   -0.962086   -3.092503    0.022935    0.999239    0.999212
# std      0.016850    0.053188    0.012327    0.011618    0.000278    0.000363
# min      1.040730   -1.098836   -3.126154   -0.011489    0.998457    0.997780
# 25%      1.055670   -0.988019   -3.101130    0.015374    0.999037    0.998983
# 50%      1.064453   -0.956160   -3.091743    0.023825    0.999196    0.999246
# 75%      1.073214   -0.929190   -3.085015    0.029682    0.999449    0.999460
# max      1.123123   -0.858910   -3.062429    0.047971    1.000058    1.000104
#        status        fval           r         A_d     alpha_d      beta_d  \
# count   100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean      0.0  385.224698    0.000199   14.237726   -0.804438    1.650605
# std       0.0   27.366084    0.000290    0.553239    0.040579    0.006214
# min       0.0  320.602085   -0.000769   13.695313   -0.872593    1.634649
# 25%       0.0  365.729573   -0.000006   13.732852   -0.842028    1.646113
# 50%       0.0  381.256548    0.000185   13.748255   -0.782511    1.649806
# 75%       0.0  406.108876    0.000408   14.805405   -0.771683    1.655122
# max       0.0  454.962811    0.000858   15.174451   -0.686068    1.665139
#
#               A_s     alpha_s      beta_s     epsilon     Delta_d     Delta_s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.067115   -0.958910   -3.092746    0.022979    0.999247    0.999205
# std      0.019086    0.049723    0.012380    0.012090    0.000275    0.000361
# min      1.037027   -1.098832   -3.128378   -0.011745    0.998458    0.997774
# 25%      1.053404   -0.987268   -3.101579    0.014294    0.999066    0.998960
# 50%      1.065166   -0.958184   -3.092019    0.024420    0.999206    0.999252
# 75%      1.074129   -0.927504   -3.084657    0.031177    0.999433    0.999463
# max      1.139802   -0.855757   -3.063139    0.048106    1.000059    1.000008
# 2.511210261998243e-06 4.251070865137821e-05
